# %% [markdown]
# # Regularization and Hyperparameter Tuning using Fashion-MNIST
#
# **Author**: Tianxiang (Adam) Gao <br>
# **Course**: CSC 383 / 483 – Applied Deep Learning <br>
# **Description**:
# In this assignment, you will explore how neural networks can **overfit** training data and how **regularization** techniques such as dropout and weight decay can improve **generalization**.
#
# You will also experiment with **hyperparameter tuning**, adjusting parameters like the learning rate and dropout rate to find combinations that lead to better model performance.

# %% [markdown]
# ## Setup
#
# We will first import some useful libraries:
#
# - `numpy` for numerical operations (e.g., arrays, random sampling).
# - `keras` for loading the MNIST dataset and building deep learning models.
# - `keras.layers` provides the building blocks (dense layers, convolutional layers, activation functions, etc.) to design neural networks.
# - `matplotlib` for visualizing images and plotting graphs.
# - `sklearn.model_selection` for splitting a validation set from the training data.

# %%
import numpy as np
import keras
from keras import layers, regularizers
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Prepare the Data [0/0]
#
# 1. Use `keras.datasets.fashion_mnist.load_data()` to load the **Fashion-MNIST** training and test sets.
# 2. Normalize all pixel values from integers in the range **[0, 255]** to floating-point numbers between **0 and 1**.

# %%
(x_train_full, y_train_full), (x_test, y_test) = keras.datasets.fashion_mnist.load_data()
x_train_full = x_train_full.astype("float32") / 255.0
y_train_full = y_train_full.squeeze().astype("int32")
x_test = x_test.astype("float32") / 255.0
y_test = y_test.squeeze().astype("int32")
print("x_train shape:", x_train_full.shape)
num_classes, input_shape = 10, x_train_full.shape[1:]
print("num_classes:", num_classes)
print("input_shape:", input_shape)
# Out:
# x_train shape: (60000, 28, 28)
# num_classes: 10
# input_shape: (28, 28)

# %% [markdown]
# ## Visualize the Data [0/0]
#
# 3. Randomly select **9 images** from the training set `x_train`. Display them in a **3×3 grid** using Matplotlib (`plt.subplot`). For each image, show its corresponding **class label** (from `y_train`) as the subplot title.

# %%
indices = np.random.choice(len(x_train_full), 9, replace=False)

plt.figure(figsize=(6, 6))
for i, idx in enumerate(indices):
    plt.subplot(3, 3, i + 1)
    plt.imshow(x_train_full[idx], cmap="gray")
    # plt.imshow(x_train_full[idx])
    plt.title(f"Label: {y_train_full[idx]}")
    plt.axis("off")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Validation Set [10/10]
#
# 4. We will use `train_test_split()` split **50%** of the images from the training dataset to create a **validation set**,
#    which will be used to help us **tune the hyperparameters** during training.

# %%
x_train, x_val, y_train, y_val = train_test_split(
    x_train_full, y_train_full, test_size=0.5, random_state=42, shuffle=True
)

print("Train subset:", x_train.shape)
print("Validation subset:", x_val.shape)
print("Test set:", x_test.shape)
# Out:
# Train subset: (30000, 28, 28)
# Validation subset: (30000, 28, 28)
# Test set: (10000, 28, 28)

# %% [markdown]
# ## Build the Model [30/30]
#
# 5. Implement a helper function `make_model()`
#    that returns a simple **two-layer MLP** built using `keras.Sequential` with the following layers:
#    - **Input layer**: accepts images of shape `input_shape`.
#    - **Flatten layer**: converts each 2D image into a 1D vector.
#    - **Dense layer**: fully connected layer with `width` hidden units and `"relu"` activation.
#    - **Dropout layer**: randomly drops a fraction of hidden activations (`dropout_rate`) during training
#      to prevent overfitting. Skip this layer if `dropout_rate = 0`.
#    - **Output layer**: fully connected layer with `num_classes` units (one per class) and `"softmax"` activation.
#
# 6. Create a `base_model` using your helper function and inspect the model by calling `model.summary()` to display the network architecture, output shapes, and number of parameters in each layer.
#
# 7. Save the `initial_weights` of the `base_model` for reuse in optimizer comparisons.

# %%
def make_model(num_classes, input_shape, width=128, dropout_rate=0.0):
    model = keras.Sequential([
        layers.Flatten(input_shape=input_shape),
        layers.Dense(width, activation='relu'),
        layers.Dropout(dropout_rate),
        layers.Dense(num_classes, activation='softmax')
    ])
    return model

base_model = make_model(num_classes, input_shape, width=128)
base_model.summary()

initial_weights = base_model.get_weights()
# Out:
# /Users/asadkhan/workspace/depaul/applied-deep-learning/.venv/lib/python3.13/site-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten (Flatten)               │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │       100,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 101,770 (397.54 KB)
#  Trainable params: 101,770 (397.54 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Define Optimizer Function [0/0]
#
# 8. To easily switch between different optimization algorithms, copy and paste the helper function
#    `get_optimizer()` from previous assignments.
#    This function should return the corresponding **Keras optimizer object** based on its name.
#
#    Implement the function with the following behavior:
#    - `"sgd"` → standard **stochastic gradient descent (SGD)**.
#    - `"momentum"` → **SGD with momentum** (`momentum=0.9`).
#    - `"rmsprop"` → **RMSprop** optimizer (adaptive learning rate).
#    - `"adam"` → **Adam** optimizer (adaptive learning rate with momentum).
#    - Raise a `ValueError` if an unknown name is provided.

# %%
def get_optimizer(name, lr=1e-3):
    if name == "sgd":
        return keras.optimizers.SGD(learning_rate=lr)
    if name == "momentum":
        return keras.optimizers.SGD(learning_rate=lr, momentum=0.9)
    if name == "rmsprop":
        return keras.optimizers.RMSprop(learning_rate=lr)
    if name == "adam":
        return keras.optimizers.Adam(learning_rate=lr)
    raise ValueError(f"Unknown optimizer: {name}")

# %% [markdown]
# ## Train and Compare Optimizers [20/20]
#
# 9. We will also define a helper function `train()` to train the model using different optimization choices.
#    This function is adapted from previous assignments and includes additional input arguments such as
#    `dropout_rate`, `lr`, and `width`.
#
#    The function should:
#    - Recreate a **fresh model** via `make_model(...)`.
#    - **Reset** to the same `initial_weights` to ensure all optimizers start from the same point.
#    - Build the optimizer using `get_optimizer(name, lr)`.
#    - **Compile** the model with `loss="sparse_categorical_crossentropy"` and `metrics=["accuracy"]`.
#    - **Train** the model on `(x_train, y_train)` and evaluate it using the validation data `(x_val, y_val)`.
#    - **Return** the training `History` object for later comparison.

# %%
def train(name, dropout_rate=0.0, lr=1e-3, batch_size=64, width=128, epochs=100):
  model = make_model(num_classes, input_shape, width=width, dropout_rate=dropout_rate)
  model.set_weights(initial_weights)
  opt = get_optimizer(name, lr=lr)
  model.compile(loss="sparse_categorical_crossentropy", optimizer=opt, metrics=["accuracy"])
  print(f"\n===Training with {name}===")
  hist = model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs, validation_data=(x_val, y_val), verbose=1)
  return hist

# %% [markdown]
# ## Experiment: Training with SGD [5/5]
#
# 10. Now train your model using **stochastic gradient descent (SGD)** with a high learning rate (`lr=1e-1`) and **no dropout**. This setup will intentionally cause **overfitting** or even unstable training, allowing you to observe how training and validation accuracy diverge.

# %%
hist = train("sgd", dropout_rate=0.0, lr=1e-1)
# Out:
# ===Training with sgd===
# Epoch 1/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.7638 - loss: 0.6769 - val_accuracy: 0.8347 - val_loss: 0.4930
# Epoch 2/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 742us/step - accuracy: 0.8280 - loss: 0.4815 - val_accuracy: 0.8377 - val_loss: 0.4577
# Epoch 3/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 775us/step - accuracy: 0.8449 - loss: 0.4318 - val_accuracy: 0.8526 - val_loss: 0.4172
# Epoch 4/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 771us/step - accuracy: 0.8555 - loss: 0.4007 - val_accuracy: 0.8563 - val_loss: 0.4038
# Epoch 5/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 821us/step - accuracy: 0.8655 - loss: 0.3762 - val_accuracy: 0.8188 - val_loss: 0.4870
# Epoch 6/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 729us/step - accuracy: 0.8706 - loss: 0.3593 - val_accuracy: 0.8386 - val_loss: 0.4450
# Epoch 7/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 738us/step - accuracy: 0.8751 - loss: 0.3455 - val_accuracy: 0.8629 - val_loss: 0.3860
# Epoch 8/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 778us/step - accuracy: 0.8791 - loss: 0.3320 - val_accuracy: 0.8668 - val_loss: 0.3686
# Epoch 9/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 777us/step - accuracy: 0.8835 - loss: 0.3208 - val_accuracy: 0.8651 - val_loss: 0.3774
# Epoch 10/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 881us/step - accuracy: 0.8871 - loss: 0.3116 - val_accuracy: 0.8537 - val_loss: 0.3970
# Epoch 11/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 778us/step - accuracy: 0.8908 - loss: 0.3025 - val_accuracy: 0.8703 - val_loss: 0.3670
# Epoch 12/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 773us/step - accuracy: 0.8927 - loss: 0.2965 - val_accuracy: 0.8731 - val_loss: 0.3566
# Epoch 13/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 736us/step - accuracy: 0.8958 - loss: 0.2877 - val_accuracy: 0.8647 - val_loss: 0.3717
# Epoch 14/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 796us/step - accuracy: 0.8994 - loss: 0.2807 - val_accuracy: 0.8813 - val_loss: 0.3363
# Epoch 15/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 787us/step - accuracy: 0.8998 - loss: 0.2739 - val_accuracy: 0.8737 - val_loss: 0.3529
# Epoch 16/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 783us/step - accuracy: 0.9029 - loss: 0.2689 - val_accuracy: 0.8736 - val_loss: 0.3584
# Epoch 17/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 798us/step - accuracy: 0.9047 - loss: 0.2604 - val_accuracy: 0.8810 - val_loss: 0.3284
# Epoch 18/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 747us/step - accuracy: 0.9049 - loss: 0.2552 - val_accuracy: 0.8806 - val_loss: 0.3303
# Epoch 19/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 759us/step - accuracy: 0.9079 - loss: 0.2521 - val_accuracy: 0.8736 - val_loss: 0.3527
# Epoch 20/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 754us/step - accuracy: 0.9075 - loss: 0.2467 - val_accuracy: 0.8741 - val_loss: 0.3540
# Epoch 21/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 770us/step - accuracy: 0.9127 - loss: 0.2421 - val_accuracy: 0.8766 - val_loss: 0.3532
# Epoch 22/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 746us/step - accuracy: 0.9148 - loss: 0.2382 - val_accuracy: 0.8683 - val_loss: 0.3627
# Epoch 23/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 761us/step - accuracy: 0.9144 - loss: 0.2331 - val_accuracy: 0.8834 - val_loss: 0.3279
# Epoch 24/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 763us/step - accuracy: 0.9173 - loss: 0.2278 - val_accuracy: 0.8855 - val_loss: 0.3250
# Epoch 25/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 763us/step - accuracy: 0.9211 - loss: 0.2216 - val_accuracy: 0.8755 - val_loss: 0.3535
# Epoch 26/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 821us/step - accuracy: 0.9200 - loss: 0.2202 - val_accuracy: 0.8772 - val_loss: 0.3478
# Epoch 27/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 754us/step - accuracy: 0.9222 - loss: 0.2137 - val_accuracy: 0.8810 - val_loss: 0.3444
# Epoch 28/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 744us/step - accuracy: 0.9240 - loss: 0.2128 - val_accuracy: 0.8640 - val_loss: 0.3808
# Epoch 29/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 740us/step - accuracy: 0.9247 - loss: 0.2093 - val_accuracy: 0.8722 - val_loss: 0.3623
# Epoch 30/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 738us/step - accuracy: 0.9265 - loss: 0.2024 - val_accuracy: 0.8766 - val_loss: 0.3567
# Epoch 31/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 736us/step - accuracy: 0.9264 - loss: 0.1998 - val_accuracy: 0.8880 - val_loss: 0.3259
# Epoch 32/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 757us/step - accuracy: 0.9273 - loss: 0.1989 - val_accuracy: 0.8785 - val_loss: 0.3444
# Epoch 33/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 743us/step - accuracy: 0.9301 - loss: 0.1928 - val_accuracy: 0.8857 - val_loss: 0.3266
# Epoch 34/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 744us/step - accuracy: 0.9323 - loss: 0.1893 - val_accuracy: 0.8714 - val_loss: 0.3715
# Epoch 35/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 741us/step - accuracy: 0.9315 - loss: 0.1881 - val_accuracy: 0.8830 - val_loss: 0.3468
# Epoch 36/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 744us/step - accuracy: 0.9358 - loss: 0.1846 - val_accuracy: 0.8800 - val_loss: 0.3439
# Epoch 37/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 745us/step - accuracy: 0.9350 - loss: 0.1809 - val_accuracy: 0.8833 - val_loss: 0.3444
# Epoch 38/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 734us/step - accuracy: 0.9356 - loss: 0.1778 - val_accuracy: 0.8837 - val_loss: 0.3415
# Epoch 39/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 804us/step - accuracy: 0.9360 - loss: 0.1744 - val_accuracy: 0.8854 - val_loss: 0.3375
# Epoch 40/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 743us/step - accuracy: 0.9380 - loss: 0.1709 - val_accuracy: 0.8805 - val_loss: 0.3560
# Epoch 41/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 745us/step - accuracy: 0.9385 - loss: 0.1689 - val_accuracy: 0.8859 - val_loss: 0.3392
# Epoch 42/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 738us/step - accuracy: 0.9397 - loss: 0.1665 - val_accuracy: 0.8861 - val_loss: 0.3390
# Epoch 43/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 742us/step - accuracy: 0.9409 - loss: 0.1638 - val_accuracy: 0.8827 - val_loss: 0.3552
# Epoch 44/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 777us/step - accuracy: 0.9421 - loss: 0.1624 - val_accuracy: 0.8837 - val_loss: 0.3494
# Epoch 45/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 772us/step - accuracy: 0.9429 - loss: 0.1589 - val_accuracy: 0.8847 - val_loss: 0.3475
# Epoch 46/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 747us/step - accuracy: 0.9456 - loss: 0.1536 - val_accuracy: 0.8853 - val_loss: 0.3488
# Epoch 47/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 750us/step - accuracy: 0.9460 - loss: 0.1530 - val_accuracy: 0.8675 - val_loss: 0.3979
# Epoch 48/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 738us/step - accuracy: 0.9450 - loss: 0.1540 - val_accuracy: 0.8832 - val_loss: 0.3527
# Epoch 49/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 748us/step - accuracy: 0.9460 - loss: 0.1482 - val_accuracy: 0.8822 - val_loss: 0.3672
# Epoch 50/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 744us/step - accuracy: 0.9491 - loss: 0.1440 - val_accuracy: 0.8846 - val_loss: 0.3502
# Epoch 51/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 817us/step - accuracy: 0.9485 - loss: 0.1468 - val_accuracy: 0.8817 - val_loss: 0.3777
# Epoch 52/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 743us/step - accuracy: 0.9482 - loss: 0.1429 - val_accuracy: 0.8739 - val_loss: 0.3849
# Epoch 53/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 744us/step - accuracy: 0.9517 - loss: 0.1385 - val_accuracy: 0.8677 - val_loss: 0.4137
# Epoch 54/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 756us/step - accuracy: 0.9511 - loss: 0.1369 - val_accuracy: 0.8799 - val_loss: 0.3902
# Epoch 55/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 746us/step - accuracy: 0.9529 - loss: 0.1342 - val_accuracy: 0.8819 - val_loss: 0.3700
# Epoch 56/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 746us/step - accuracy: 0.9513 - loss: 0.1349 - val_accuracy: 0.8796 - val_loss: 0.3953
# Epoch 57/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 759us/step - accuracy: 0.9551 - loss: 0.1271 - val_accuracy: 0.8850 - val_loss: 0.3785
# Epoch 58/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 746us/step - accuracy: 0.9553 - loss: 0.1284 - val_accuracy: 0.8853 - val_loss: 0.3690
# Epoch 59/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 741us/step - accuracy: 0.9553 - loss: 0.1265 - val_accuracy: 0.8774 - val_loss: 0.3909
# Epoch 60/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 748us/step - accuracy: 0.9565 - loss: 0.1228 - val_accuracy: 0.8857 - val_loss: 0.3759
# Epoch 61/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 746us/step - accuracy: 0.9563 - loss: 0.1222 - val_accuracy: 0.8827 - val_loss: 0.3857
# Epoch 62/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 741us/step - accuracy: 0.9573 - loss: 0.1222 - val_accuracy: 0.8867 - val_loss: 0.3804
# Epoch 63/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 792us/step - accuracy: 0.9572 - loss: 0.1197 - val_accuracy: 0.8756 - val_loss: 0.4289
# Epoch 64/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 758us/step - accuracy: 0.9591 - loss: 0.1185 - val_accuracy: 0.8713 - val_loss: 0.4363
# Epoch 65/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 755us/step - accuracy: 0.9600 - loss: 0.1150 - val_accuracy: 0.8884 - val_loss: 0.3751
# Epoch 66/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 747us/step - accuracy: 0.9602 - loss: 0.1128 - val_accuracy: 0.8772 - val_loss: 0.4149
# Epoch 67/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 751us/step - accuracy: 0.9594 - loss: 0.1135 - val_accuracy: 0.8879 - val_loss: 0.3754
# Epoch 68/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 754us/step - accuracy: 0.9623 - loss: 0.1088 - val_accuracy: 0.8855 - val_loss: 0.3900
# Epoch 69/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 746us/step - accuracy: 0.9616 - loss: 0.1080 - val_accuracy: 0.8787 - val_loss: 0.4127
# Epoch 70/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 756us/step - accuracy: 0.9612 - loss: 0.1072 - val_accuracy: 0.8832 - val_loss: 0.3973
# Epoch 71/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 743us/step - accuracy: 0.9639 - loss: 0.1061 - val_accuracy: 0.8733 - val_loss: 0.4375
# Epoch 72/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 738us/step - accuracy: 0.9636 - loss: 0.1035 - val_accuracy: 0.8617 - val_loss: 0.4898
# Epoch 73/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 792us/step - accuracy: 0.9638 - loss: 0.1018 - val_accuracy: 0.8828 - val_loss: 0.4123
# Epoch 74/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 865us/step - accuracy: 0.9650 - loss: 0.0981 - val_accuracy: 0.8844 - val_loss: 0.4049
# Epoch 75/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 743us/step - accuracy: 0.9658 - loss: 0.0969 - val_accuracy: 0.8805 - val_loss: 0.4374
# Epoch 76/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 755us/step - accuracy: 0.9666 - loss: 0.0965 - val_accuracy: 0.8831 - val_loss: 0.4084
# Epoch 77/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 738us/step - accuracy: 0.9660 - loss: 0.0959 - val_accuracy: 0.8802 - val_loss: 0.4307
# Epoch 78/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 742us/step - accuracy: 0.9693 - loss: 0.0930 - val_accuracy: 0.8653 - val_loss: 0.5086
# Epoch 79/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 739us/step - accuracy: 0.9682 - loss: 0.0929 - val_accuracy: 0.8843 - val_loss: 0.4170
# Epoch 80/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 740us/step - accuracy: 0.9701 - loss: 0.0895 - val_accuracy: 0.8682 - val_loss: 0.4791
# Epoch 81/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 754us/step - accuracy: 0.9675 - loss: 0.0908 - val_accuracy: 0.8844 - val_loss: 0.4206
# Epoch 82/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 738us/step - accuracy: 0.9700 - loss: 0.0883 - val_accuracy: 0.8843 - val_loss: 0.4255
# Epoch 83/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 764us/step - accuracy: 0.9683 - loss: 0.0897 - val_accuracy: 0.8808 - val_loss: 0.4177
# Epoch 84/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 796us/step - accuracy: 0.9705 - loss: 0.0843 - val_accuracy: 0.8804 - val_loss: 0.4305
# Epoch 85/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 749us/step - accuracy: 0.9706 - loss: 0.0843 - val_accuracy: 0.8650 - val_loss: 0.4916
# Epoch 86/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 743us/step - accuracy: 0.9721 - loss: 0.0820 - val_accuracy: 0.8843 - val_loss: 0.4267
# Epoch 87/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 745us/step - accuracy: 0.9725 - loss: 0.0795 - val_accuracy: 0.8708 - val_loss: 0.4900
# Epoch 88/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 760us/step - accuracy: 0.9722 - loss: 0.0800 - val_accuracy: 0.8809 - val_loss: 0.4407
# Epoch 89/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 745us/step - accuracy: 0.9734 - loss: 0.0776 - val_accuracy: 0.8853 - val_loss: 0.4350
# Epoch 90/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 734us/step - accuracy: 0.9739 - loss: 0.0778 - val_accuracy: 0.8828 - val_loss: 0.4314
# Epoch 91/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 740us/step - accuracy: 0.9767 - loss: 0.0734 - val_accuracy: 0.8857 - val_loss: 0.4313
# Epoch 92/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 746us/step - accuracy: 0.9748 - loss: 0.0756 - val_accuracy: 0.8788 - val_loss: 0.4521
# Epoch 93/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 757us/step - accuracy: 0.9760 - loss: 0.0734 - val_accuracy: 0.8831 - val_loss: 0.4438
# Epoch 94/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 853us/step - accuracy: 0.9761 - loss: 0.0703 - val_accuracy: 0.8783 - val_loss: 0.4593
# Epoch 95/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 804us/step - accuracy: 0.9744 - loss: 0.0744 - val_accuracy: 0.8777 - val_loss: 0.4772
# Epoch 96/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 755us/step - accuracy: 0.9764 - loss: 0.0703 - val_accuracy: 0.8795 - val_loss: 0.4702
# Epoch 97/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 748us/step - accuracy: 0.9784 - loss: 0.0671 - val_accuracy: 0.8832 - val_loss: 0.4448
# Epoch 98/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 748us/step - accuracy: 0.9781 - loss: 0.0668 - val_accuracy: 0.8860 - val_loss: 0.4343
# Epoch 99/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 746us/step - accuracy: 0.9767 - loss: 0.0669 - val_accuracy: 0.8727 - val_loss: 0.5352
# Epoch 100/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 742us/step - accuracy: 0.9800 - loss: 0.0638 - val_accuracy: 0.8777 - val_loss: 0.4992

# %% [markdown]
# ## Plot Training and Validation Curves [5/5]
#
# 11. Define a helper function `plot_history(hist, log_scale=False)` to visualize the **training** and **validation** loss curves from the `History` object returned by `model.fit()`.
#     - Plot both **training loss** and **validation loss** on the same graph.
#     - Add axis labels, a title, and a legend for clarity.
#     - Use the optional argument `log_scale=True` to show the loss on a logarithmic scale.

# %%
def plot_history(hist, log_scale=False):
  plt.figure(figsize=(8,5))
  plt.plot(hist.history["loss"], color="blue", linestyle="-", label="train")
  plt.plot(hist.history["val_loss"], color="red", linestyle="--", label="val")

  plt.xlabel("Epoch")
  plt.ylabel("Loss")
  plt.title("Training vs Validation Loss")
  plt.legend()
  plt.grid(True, which="both", ls=":")
  if log_scale:
      plt.yscale("log")
      plt.ylabel("Loss (log scale)")
  plt.show()

# %%
# Plot the result
plot_history(hist)  # Standard plot
plot_history(hist, log_scale=True)  # Logarithmic scale

# %% [markdown]
# ## Experiment: Training with SGD + Dropout [5/5]
#
# 12. Now train the model again using **SGD** with the same learning rate (`lr=1e-1`) but add **dropout = 0.5** to apply regularization. Compare the results with the previous run to see how dropout helps reduce overfitting and improves validation performance.

# %%
hist = train("sgd", dropout_rate=0.5, lr=1e-1, width=128)
# Out:
# ===Training with sgd===
# Epoch 1/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 898us/step - accuracy: 0.7207 - loss: 0.7957 - val_accuracy: 0.7863 - val_loss: 0.5589
# Epoch 2/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 850us/step - accuracy: 0.7950 - loss: 0.5776 - val_accuracy: 0.8105 - val_loss: 0.5155
# Epoch 3/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 806us/step - accuracy: 0.8134 - loss: 0.5190 - val_accuracy: 0.8336 - val_loss: 0.4544
# Epoch 4/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 884us/step - accuracy: 0.8249 - loss: 0.4893 - val_accuracy: 0.8444 - val_loss: 0.4245
# Epoch 5/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 791us/step - accuracy: 0.8304 - loss: 0.4658 - val_accuracy: 0.8445 - val_loss: 0.4209
# Epoch 6/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 816us/step - accuracy: 0.8356 - loss: 0.4563 - val_accuracy: 0.8519 - val_loss: 0.4020
# Epoch 7/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 924us/step - accuracy: 0.8426 - loss: 0.4382 - val_accuracy: 0.8584 - val_loss: 0.3901
# Epoch 8/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 840us/step - accuracy: 0.8444 - loss: 0.4326 - val_accuracy: 0.8534 - val_loss: 0.3927
# Epoch 9/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 835us/step - accuracy: 0.8475 - loss: 0.4220 - val_accuracy: 0.8603 - val_loss: 0.3795
# Epoch 10/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 779us/step - accuracy: 0.8515 - loss: 0.4101 - val_accuracy: 0.8669 - val_loss: 0.3681
# Epoch 11/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 831us/step - accuracy: 0.8517 - loss: 0.4060 - val_accuracy: 0.8698 - val_loss: 0.3644
# Epoch 12/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 858us/step - accuracy: 0.8568 - loss: 0.3979 - val_accuracy: 0.8589 - val_loss: 0.3798
# Epoch 13/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 785us/step - accuracy: 0.8583 - loss: 0.3935 - val_accuracy: 0.8659 - val_loss: 0.3627
# Epoch 14/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 930us/step - accuracy: 0.8598 - loss: 0.3896 - val_accuracy: 0.8666 - val_loss: 0.3665
# Epoch 15/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8620 - loss: 0.3847 - val_accuracy: 0.8670 - val_loss: 0.3675
# Epoch 16/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 775us/step - accuracy: 0.8622 - loss: 0.3772 - val_accuracy: 0.8707 - val_loss: 0.3524
# Epoch 17/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 817us/step - accuracy: 0.8660 - loss: 0.3713 - val_accuracy: 0.8724 - val_loss: 0.3480
# Epoch 18/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 933us/step - accuracy: 0.8655 - loss: 0.3666 - val_accuracy: 0.8739 - val_loss: 0.3472
# Epoch 19/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8676 - loss: 0.3652 - val_accuracy: 0.8750 - val_loss: 0.3477
# Epoch 20/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 876us/step - accuracy: 0.8702 - loss: 0.3622 - val_accuracy: 0.8725 - val_loss: 0.3500
# Epoch 21/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 910us/step - accuracy: 0.8717 - loss: 0.3537 - val_accuracy: 0.8756 - val_loss: 0.3428
# Epoch 22/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 852us/step - accuracy: 0.8710 - loss: 0.3507 - val_accuracy: 0.8732 - val_loss: 0.3465
# Epoch 23/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 777us/step - accuracy: 0.8716 - loss: 0.3493 - val_accuracy: 0.8777 - val_loss: 0.3357
# Epoch 24/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 773us/step - accuracy: 0.8732 - loss: 0.3458 - val_accuracy: 0.8689 - val_loss: 0.3476
# Epoch 25/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 853us/step - accuracy: 0.8740 - loss: 0.3462 - val_accuracy: 0.8664 - val_loss: 0.3595
# Epoch 26/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 802us/step - accuracy: 0.8766 - loss: 0.3388 - val_accuracy: 0.8736 - val_loss: 0.3547
# Epoch 27/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 828us/step - accuracy: 0.8770 - loss: 0.3342 - val_accuracy: 0.8580 - val_loss: 0.3826
# Epoch 28/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 800us/step - accuracy: 0.8765 - loss: 0.3330 - val_accuracy: 0.8716 - val_loss: 0.3536
# Epoch 29/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 842us/step - accuracy: 0.8790 - loss: 0.3326 - val_accuracy: 0.8787 - val_loss: 0.3359
# Epoch 30/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 793us/step - accuracy: 0.8796 - loss: 0.3304 - val_accuracy: 0.8760 - val_loss: 0.3425
# Epoch 31/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 845us/step - accuracy: 0.8818 - loss: 0.3251 - val_accuracy: 0.8802 - val_loss: 0.3296
# Epoch 32/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 796us/step - accuracy: 0.8813 - loss: 0.3249 - val_accuracy: 0.8813 - val_loss: 0.3298
# Epoch 33/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 781us/step - accuracy: 0.8822 - loss: 0.3211 - val_accuracy: 0.8805 - val_loss: 0.3372
# Epoch 34/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 795us/step - accuracy: 0.8830 - loss: 0.3201 - val_accuracy: 0.8788 - val_loss: 0.3344
# Epoch 35/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 785us/step - accuracy: 0.8836 - loss: 0.3149 - val_accuracy: 0.8802 - val_loss: 0.3304
# Epoch 36/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 796us/step - accuracy: 0.8843 - loss: 0.3153 - val_accuracy: 0.8759 - val_loss: 0.3419
# Epoch 37/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 776us/step - accuracy: 0.8851 - loss: 0.3119 - val_accuracy: 0.8773 - val_loss: 0.3375
# Epoch 38/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 787us/step - accuracy: 0.8849 - loss: 0.3102 - val_accuracy: 0.8802 - val_loss: 0.3318
# Epoch 39/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 780us/step - accuracy: 0.8852 - loss: 0.3079 - val_accuracy: 0.8774 - val_loss: 0.3386
# Epoch 40/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 822us/step - accuracy: 0.8847 - loss: 0.3094 - val_accuracy: 0.8822 - val_loss: 0.3315
# Epoch 41/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 777us/step - accuracy: 0.8873 - loss: 0.3063 - val_accuracy: 0.8826 - val_loss: 0.3275
# Epoch 42/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 770us/step - accuracy: 0.8873 - loss: 0.3036 - val_accuracy: 0.8728 - val_loss: 0.3478
# Epoch 43/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 779us/step - accuracy: 0.8863 - loss: 0.3037 - val_accuracy: 0.8826 - val_loss: 0.3319
# Epoch 44/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 773us/step - accuracy: 0.8893 - loss: 0.2995 - val_accuracy: 0.8819 - val_loss: 0.3286
# Epoch 45/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 776us/step - accuracy: 0.8880 - loss: 0.2937 - val_accuracy: 0.8822 - val_loss: 0.3321
# Epoch 46/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 771us/step - accuracy: 0.8890 - loss: 0.2995 - val_accuracy: 0.8765 - val_loss: 0.3357
# Epoch 47/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 770us/step - accuracy: 0.8906 - loss: 0.2932 - val_accuracy: 0.8831 - val_loss: 0.3283
# Epoch 48/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 777us/step - accuracy: 0.8900 - loss: 0.2946 - val_accuracy: 0.8773 - val_loss: 0.3399
# Epoch 49/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 780us/step - accuracy: 0.8915 - loss: 0.2916 - val_accuracy: 0.8797 - val_loss: 0.3387
# Epoch 50/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 821us/step - accuracy: 0.8912 - loss: 0.2900 - val_accuracy: 0.8824 - val_loss: 0.3240
# Epoch 51/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 773us/step - accuracy: 0.8911 - loss: 0.2940 - val_accuracy: 0.8822 - val_loss: 0.3354
# Epoch 52/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 783us/step - accuracy: 0.8905 - loss: 0.2882 - val_accuracy: 0.8796 - val_loss: 0.3372
# Epoch 53/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 779us/step - accuracy: 0.8917 - loss: 0.2856 - val_accuracy: 0.8837 - val_loss: 0.3302
# Epoch 54/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 782us/step - accuracy: 0.8933 - loss: 0.2838 - val_accuracy: 0.8854 - val_loss: 0.3260
# Epoch 55/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 782us/step - accuracy: 0.8931 - loss: 0.2821 - val_accuracy: 0.8806 - val_loss: 0.3349
# Epoch 56/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 769us/step - accuracy: 0.8935 - loss: 0.2854 - val_accuracy: 0.8842 - val_loss: 0.3291
# Epoch 57/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 772us/step - accuracy: 0.8960 - loss: 0.2801 - val_accuracy: 0.8825 - val_loss: 0.3403
# Epoch 58/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 770us/step - accuracy: 0.8952 - loss: 0.2795 - val_accuracy: 0.8847 - val_loss: 0.3273
# Epoch 59/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 780us/step - accuracy: 0.8952 - loss: 0.2840 - val_accuracy: 0.8851 - val_loss: 0.3258
# Epoch 60/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 837us/step - accuracy: 0.8965 - loss: 0.2772 - val_accuracy: 0.8852 - val_loss: 0.3337
# Epoch 61/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 773us/step - accuracy: 0.8951 - loss: 0.2755 - val_accuracy: 0.8839 - val_loss: 0.3260
# Epoch 62/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 775us/step - accuracy: 0.8970 - loss: 0.2738 - val_accuracy: 0.8858 - val_loss: 0.3235
# Epoch 63/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 773us/step - accuracy: 0.8955 - loss: 0.2776 - val_accuracy: 0.8844 - val_loss: 0.3230
# Epoch 64/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 780us/step - accuracy: 0.8965 - loss: 0.2749 - val_accuracy: 0.8864 - val_loss: 0.3246
# Epoch 65/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 777us/step - accuracy: 0.9002 - loss: 0.2695 - val_accuracy: 0.8828 - val_loss: 0.3306
# Epoch 66/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 814us/step - accuracy: 0.8977 - loss: 0.2697 - val_accuracy: 0.8835 - val_loss: 0.3310
# Epoch 67/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 892us/step - accuracy: 0.8986 - loss: 0.2650 - val_accuracy: 0.8854 - val_loss: 0.3279
# Epoch 68/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 833us/step - accuracy: 0.8983 - loss: 0.2673 - val_accuracy: 0.8788 - val_loss: 0.3429
# Epoch 69/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 796us/step - accuracy: 0.8990 - loss: 0.2681 - val_accuracy: 0.8821 - val_loss: 0.3323
# Epoch 70/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 874us/step - accuracy: 0.9004 - loss: 0.2656 - val_accuracy: 0.8869 - val_loss: 0.3269
# Epoch 71/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 788us/step - accuracy: 0.9013 - loss: 0.2635 - val_accuracy: 0.8858 - val_loss: 0.3273
# Epoch 72/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 787us/step - accuracy: 0.9013 - loss: 0.2642 - val_accuracy: 0.8852 - val_loss: 0.3331
# Epoch 73/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 932us/step - accuracy: 0.9024 - loss: 0.2586 - val_accuracy: 0.8864 - val_loss: 0.3365
# Epoch 74/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.9003 - loss: 0.2630 - val_accuracy: 0.8858 - val_loss: 0.3332
# Epoch 75/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9016 - loss: 0.2568 - val_accuracy: 0.8740 - val_loss: 0.3572
# Epoch 76/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 892us/step - accuracy: 0.9025 - loss: 0.2598 - val_accuracy: 0.8814 - val_loss: 0.3435
# Epoch 77/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 910us/step - accuracy: 0.9025 - loss: 0.2590 - val_accuracy: 0.8857 - val_loss: 0.3386
# Epoch 78/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 786us/step - accuracy: 0.9025 - loss: 0.2569 - val_accuracy: 0.8877 - val_loss: 0.3291
# Epoch 79/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 781us/step - accuracy: 0.9041 - loss: 0.2567 - val_accuracy: 0.8874 - val_loss: 0.3342
# Epoch 80/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9029 - loss: 0.2550 - val_accuracy: 0.8854 - val_loss: 0.3364
# Epoch 81/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 841us/step - accuracy: 0.9063 - loss: 0.2525 - val_accuracy: 0.8802 - val_loss: 0.3662
# Epoch 82/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 789us/step - accuracy: 0.9069 - loss: 0.2506 - val_accuracy: 0.8852 - val_loss: 0.3308
# Epoch 83/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 807us/step - accuracy: 0.9077 - loss: 0.2482 - val_accuracy: 0.8856 - val_loss: 0.3365
# Epoch 84/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 824us/step - accuracy: 0.9052 - loss: 0.2463 - val_accuracy: 0.8874 - val_loss: 0.3375
# Epoch 85/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 919us/step - accuracy: 0.9067 - loss: 0.2488 - val_accuracy: 0.8861 - val_loss: 0.3311
# Epoch 86/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 887us/step - accuracy: 0.9062 - loss: 0.2473 - val_accuracy: 0.8850 - val_loss: 0.3363
# Epoch 87/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 820us/step - accuracy: 0.9064 - loss: 0.2466 - val_accuracy: 0.8880 - val_loss: 0.3346
# Epoch 88/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 779us/step - accuracy: 0.9064 - loss: 0.2484 - val_accuracy: 0.8840 - val_loss: 0.3380
# Epoch 89/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 788us/step - accuracy: 0.9055 - loss: 0.2457 - val_accuracy: 0.8858 - val_loss: 0.3447
# Epoch 90/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 808us/step - accuracy: 0.9077 - loss: 0.2468 - val_accuracy: 0.8863 - val_loss: 0.3393
# Epoch 91/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 789us/step - accuracy: 0.9062 - loss: 0.2466 - val_accuracy: 0.8857 - val_loss: 0.3360
# Epoch 92/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 799us/step - accuracy: 0.9090 - loss: 0.2404 - val_accuracy: 0.8827 - val_loss: 0.3439
# Epoch 93/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 846us/step - accuracy: 0.9105 - loss: 0.2381 - val_accuracy: 0.8850 - val_loss: 0.3424
# Epoch 94/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 842us/step - accuracy: 0.9075 - loss: 0.2404 - val_accuracy: 0.8854 - val_loss: 0.3407
# Epoch 95/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 779us/step - accuracy: 0.9086 - loss: 0.2425 - val_accuracy: 0.8838 - val_loss: 0.3375
# Epoch 96/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 784us/step - accuracy: 0.9070 - loss: 0.2420 - val_accuracy: 0.8872 - val_loss: 0.3405
# Epoch 97/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 779us/step - accuracy: 0.9082 - loss: 0.2402 - val_accuracy: 0.8827 - val_loss: 0.3479
# Epoch 98/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 788us/step - accuracy: 0.9083 - loss: 0.2385 - val_accuracy: 0.8839 - val_loss: 0.3372
# Epoch 99/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 795us/step - accuracy: 0.9096 - loss: 0.2366 - val_accuracy: 0.8866 - val_loss: 0.3407
# Epoch 100/100
# 469/469 ━━━━━━━━━━━━━━━━━━━━ 0s 784us/step - accuracy: 0.9085 - loss: 0.2374 - val_accuracy: 0.8854 - val_loss: 0.3364

# %%
plot_history(hist)

# %% [markdown]
# ## Hyperparameter Search: Learning Rate vs Dropout [25/25]
#
# 13. Now we will perform a simple **grid search** over two important hyperparameters: **Learning rate (`lr`)** and **Dropout rate (`dropout`)**
#
# For each combination of learning rate and dropout rate:
#
# - Build a new model using `make_model(...)`.
# - train the model for a fixed number of epochs (e.g. 20) using the **SGD** optimizer
# - and record both the **training accuracy** and **validation accuracy** from the **last epoch**.
#
# This will help us visualize which combinations lead to underfitting, overfitting, or the best generalization.

# %%
# Define search ranges
import random

learning_rates = [1e-4, 1e-3, 1e-2, 1e-1]
dropouts = [0.0, 0.2, 0.5, 0.7]

results = []  # store results in a list of dicts
trials = 10

for lr in learning_rates:
    for drop in dropouts:
        print(f"\nTraining with lr={lr}, dropout={drop}")
        model = make_model(num_classes, input_shape, width=128, dropout_rate=drop)
        model.compile(
            optimizer=keras.optimizers.SGD(learning_rate=lr),
            loss="sparse_categorical_crossentropy",
            metrics=["accuracy"]
        )
        hist = model.fit(x_train, y_train, batch_size=64, epochs=20, validation_data=(x_val, y_val), verbose=0)
        val_acc = hist.history["val_accuracy"][-1]
        train_acc = hist.history["accuracy"][-1]

        print(f"train_acc={train_acc:.3f}, val_acc={val_acc:.3f}")

        results.append([lr, drop, train_acc, val_acc])
# Out:
# Training with lr=0.0001, dropout=0.0
# train_acc=0.647, val_acc=0.653
#
# Training with lr=0.0001, dropout=0.2
# train_acc=0.599, val_acc=0.653
#
# Training with lr=0.0001, dropout=0.5
# train_acc=0.515, val_acc=0.656
#
# Training with lr=0.0001, dropout=0.7
# train_acc=0.410, val_acc=0.595
#
# Training with lr=0.001, dropout=0.0
# train_acc=0.799, val_acc=0.798
#
# Training with lr=0.001, dropout=0.2
# train_acc=0.763, val_acc=0.786
#
# Training with lr=0.001, dropout=0.5
# train_acc=0.723, val_acc=0.769
#
# Training with lr=0.001, dropout=0.7
# train_acc=0.685, val_acc=0.759
#
# Training with lr=0.01, dropout=0.0
# train_acc=0.861, val_acc=0.855
#
# Training with lr=0.01, dropout=0.2
# train_acc=0.851, val_acc=0.854
#
# Training with lr=0.01, dropout=0.5
# train_acc=0.832, val_acc=0.850
#
# Training with lr=0.01, dropout=0.7
# train_acc=0.806, val_acc=0.840
#
# Training with lr=0.1, dropout=0.0
# train_acc=0.910, val_acc=0.873
#
# Training with lr=0.1, dropout=0.2
# train_acc=0.896, val_acc=0.878
#
# Training with lr=0.1, dropout=0.5
# train_acc=0.870, val_acc=0.876
#
# Training with lr=0.1, dropout=0.7
# train_acc=0.829, val_acc=0.866

# %%
print("\n=== Summary ===")
print(" lr\t dropout\t train_acc\t val_acc")
for r in results:
    print(f"{r[0]:.0e}\t {r[1]:.1f}\t\t {r[2]:.3f}\t\t {r[3]:.3f}")
# Out:
# === Summary ===
#  lr	 dropout	 train_acc	 val_acc
# 1e-04	 0.0		 0.647		 0.653
# 1e-04	 0.2		 0.599		 0.653
# 1e-04	 0.5		 0.515		 0.656
# 1e-04	 0.7		 0.410		 0.595
# 1e-03	 0.0		 0.799		 0.798
# 1e-03	 0.2		 0.763		 0.786
# 1e-03	 0.5		 0.723		 0.769
# 1e-03	 0.7		 0.685		 0.759
# 1e-02	 0.0		 0.861		 0.855
# 1e-02	 0.2		 0.851		 0.854
# 1e-02	 0.5		 0.832		 0.850
# 1e-02	 0.7		 0.806		 0.840
# 1e-01	 0.0		 0.910		 0.873
# 1e-01	 0.2		 0.896		 0.878
# 1e-01	 0.5		 0.870		 0.876
# 1e-01	 0.7		 0.829		 0.866

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.lines import Line2D

# Convert results to NumPy array
results = np.array(results, dtype=float)
lr = results[:, 0]
drop = results[:, 1]
train_acc = results[:, 2]
val_acc = results[:, 3]

# Normalize validation accuracy to [0, 1]
val_acc_norm = (val_acc - val_acc.min()) / (val_acc.max() - val_acc.min() + 1e-8)

# Exaggerate size differences for visibility
sizes = 200 + 4000 * (val_acc_norm ** 3)

plt.figure(figsize=(8, 6))
plt.scatter(
    lr, drop,
    s=sizes,
    color="royalblue",
    alpha=0.7,
    edgecolors="black",
    linewidths=0.5
)

plt.xscale("log")
plt.xlabel("Learning Rate (log scale)")
plt.ylabel("Dropout Rate")
plt.title("Validation Accuracy across Learning Rate and Dropout\n(dot size ∝ validation accuracy)")
plt.grid(True, ls="--", lw=0.5)

# Identify best point
best_idx = np.argmax(val_acc)
best_lr, best_drop, best_val = lr[best_idx], drop[best_idx], val_acc[best_idx]

# Draw dashed guide lines for the best point
plt.axvline(best_lr, color="red", linestyle="--", linewidth=1)
plt.axhline(best_drop, color="red", linestyle="--", linewidth=1)

# Mark the best point with a circle
plt.scatter(best_lr, best_drop, s=2500, facecolors="none", edgecolors="red", linewidths=2)

# Add annotation
plt.text(best_lr, best_drop + 0.05,
         f"Best val_acc = {best_val:.3f}\n(lr={best_lr:.0e}, dropout={best_drop:.1f})",
         color="red", fontsize=10, ha="center", va="bottom",
         bbox=dict(facecolor="white", alpha=0.7, edgecolor="none"))

# Create a custom line legend handle
custom_line = Line2D([0], [0], color="red", lw=1.5, linestyle="--", label="Best configuration")

# Add legend using the custom line
plt.legend(handles=[custom_line])

plt.show()
